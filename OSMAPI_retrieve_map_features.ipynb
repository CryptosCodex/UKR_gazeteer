# %%
'''
References: 
https://wiki.openstreetmap.org/wiki/Main_Page
https://www.hotosm.org/

The place name should be geocodable which means that the place name should exist in the OpenStreetMap database.
You can do a test search at 
https://www.openstreetmap.org/
https://nominatim.openstreetmap.org/
'''

#Import OSM and MatPlotLib packages
import osmnx as ox
import matplotlib.pyplot as plt

# %%
# Specify the name that is used to seach for the data
place_name = "The Hague"

# %%
# Fetch OSM street network from the location
graph = ox.graph_from_place(place_name)
# Out:
# C:\Users\Machine2\anaconda3\envs\py38-gis\lib\site-packages\osmnx\geocoder.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gdf = gdf.append(_geocode_query_to_gdf(q, wr, by_osmid))

# %%
# Plot the streets
fig, ax = ox.plot_graph(graph)

# %%
# Retrieve nodes and edges
nodes, edges = ox.graph_to_gdfs(graph)

# %%
print(nodes.head())
print(edges.head())
# Out:
#                   y         x  street_count highway  ref  \
# osmid
# 2383199   52.097200  4.299700             4     NaN  NaN
# 8145074   52.096069  4.287699             3     NaN  NaN
# 8306120   52.074182  4.297228             3     NaN  NaN
# 12087176  52.123248  4.305283             3     NaN  NaN
# 12087209  52.124546  4.305126             3     NaN  NaN
#
#                           geometry
# osmid
# 2383199   POINT (4.29970 52.09720)
# 8145074   POINT (4.28770 52.09607)
# 8306120   POINT (4.29723 52.07418)
# 12087176  POINT (4.30528 52.12325)
# 12087209  POINT (4.30513 52.12455)
#                             osmid             name      highway  oneway  \
# u       v          key
# 2383199 1114904125 0      4479168  A.W. Grootelaan      footway   False
#         45230263   0      7494882     Ver-Huëllweg  residential   False
#         358534306  0      7494882     Ver-Huëllweg  residential   False
#         1114862589 0      7494944              NaN      footway   False
# 8145074 2304997779 0    309946200     Duinmeierpad     cycleway   False
#
#                         length maxspeed  \
# u       v          key
# 2383199 1114904125 0    25.552      NaN
#         45230263   0    50.039       50
#         358534306  0     8.708       50
#         1114862589 0    96.937      NaN
# 8145074 2304997779 0     5.388      NaN
#
#                                                                geometry  \
# u       v          key
# 2383199 1114904125 0    LINESTRING (4.29970 52.09720, 4.29965 52.09697)
#         45230263   0    LINESTRING (4.29970 52.09720, 4.29899 52.09710)
#         358534306  0    LINESTRING (4.29970 52.09720, 4.29983 52.09721)
#         1114862589 0    LINESTRING (4.29970 52.09720, 4.29954 52.09807)
# 8145074 2304997779 0    LINESTRING (4.28770 52.09607, 4.28778 52.09608)
#
#                        bridge tunnel service access lanes  ref width junction
# u       v          key
# 2383199 1114904125 0      NaN    NaN     NaN    NaN   NaN  NaN   NaN      NaN
#         45230263   0      NaN    NaN     NaN    NaN   NaN  NaN   NaN      NaN
#         358534306  0      NaN    NaN     NaN    NaN   NaN  NaN   NaN      NaN
#         1114862589 0      NaN    NaN     NaN    NaN   NaN  NaN   NaN      NaN
# 8145074 2304997779 0      NaN    NaN     NaN    NaN   NaN  NaN   NaN      NaN

# %%
# Get place boundary related to the place name as a geodataframe
area = ox.geocode_to_gdf(place_name)

# Check data values
area
# Out:
# C:\Users\Machine2\anaconda3\envs\py38-gis\lib\site-packages\osmnx\geocoder.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gdf = gdf.append(_geocode_query_to_gdf(q, wr, by_osmid))
#                                             geometry  bbox_north  bbox_south  \
# 0  POLYGON ((4.18500 52.06145, 4.18941 52.05920, ...   52.135036   52.014848
#
#    bbox_east  bbox_west   place_id  osm_type  osm_id        lat       lon  \
# 0    4.42249   4.184998  284988228  relation  192737  52.079984  4.311346
#
#                             display_name     class            type  importance
# 0  The Hague, South Holland, Netherlands  boundary  administrative    0.877318

# %%
# Plot the area:
area.plot()
# Out:
# <AxesSubplot:>
